# %% [markdown]
# <a href="https://colab.research.google.com/github/simionsimon/Python-Coding-Challenge/blob/main/Feedback_Analyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Today's challenge-String Methods and Slicing**
#
# ***Project Title: Feedback Analyzer***
#
# Scenario:
#
#  A content review team wants to analyse user feedback and comments. They want to check how frequently certain words appear and extract parts of the feedback for reporting.
# Tasks:
#
# Ask the user to input a sentence (representing feedback).
#
# Count how many words are in the sentence.
#
# Check how many times the word “data” appears in the sentence, regardless of case.
#
# Extract and print the first 5 and last 5 characters of the feedback separately.
#
# Reverse the sentence and print it.

# %%
# Project Title: Feedback Analyzer #

# Ask the user to input a sentence
feedback = input("Enter your feedback: ")

# Count how many words are in the sentence
word_count = len(feedback.split())
print("Number of words:", word_count)

# Check how many times the word "data" appears in the sentence
data_count = feedback.lower().count("data")
print("Occurrences of 'data':", data_count)

# Extract first 5 and last 5 characters
print("First 5 characters:", feedback[:5])
print("Last 5 characters:", feedback[-5:])

# Reverse the sentence
print("Reversed sentence:", feedback[::-1])
# Out:
# Enter your feedback: Great Course, Good Content
# Number of words: 4
# Occurrences of 'data': 0
# First 5 characters: Great
# Last 5 characters: ntent
# Reversed sentence: tnetnoC dooG ,esruoC taerG
