# %% [markdown]
# <a href="https://colab.research.google.com/github/simionsimon/Python-Coding-Challenge/blob/main/Manage_Online_Course_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# \## **Case Study:- Manage Online Course Data**
# **Instructions:**
#
# - Create three lists of course enrollments (Python, SQL, Power BI).
#
# - Use append(), insert(), and extend() to update them.
#
# - Remove at least one course using remove() or pop().
#
# - Display the first two and last two enrollments using slicing.
#
# - Find total, max, and min enrollments using built-in functions.
#
# - Sort the lists in ascending and descending order.

# %%
# Perform operations here

# %%
python =["p1","p2","p3","p4","p5","p6","p7","p8","p9","p10"]
sql =["s1","s2","s3","s4","s5","s6","s7"]
powerbi =["pb1","pb2","pb3","pb4","pb5",]

# %%
python
# Out:
# ['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10']

# %%
sql
# Out:
# ['s1', 's2', 's3', 's4', 's5', 's6', 's7']

# %%
powerbi
# Out:
# ['pb1', 'pb2', 'pb3', 'pb4', 'pb5']

# %%
#append
python.append("p11")

# %%
python
# Out:
# ['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11']

# %%
#Insert
sql.insert(4,"s9")

# %%
sql
# Out:
# ['s1', 's2', 's3', 's4', 's9', 's5', 's6', 's7']

# %%
#Extend
powerbi.extend(["pb6","pb7"])

# %%
powerbi
# Out:
# ['pb1', 'pb2', 'pb3', 'pb4', 'pb5', 'pb6', 'pb7']
