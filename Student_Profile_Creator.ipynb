# %% [markdown]
# <a href="https://colab.research.google.com/github/simionsimon/Python-Coding-Challenge/blob/main/Student_Profile_Creator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Today's challenge-**
#
# **Introduction to Programming Languages and Python Project Title:**
#
# **Student Profile Creator**
#
#  Scenario:
#
# You are helping to build a basic student information system for a local school.
#
# The school wants to store some basic details about each student and let them update their interests.
#
# Tasks: Create variables to store the student’s name, age, and their favourite subjects they are enrolled in.
#
# Display the student’s information in a user-friendly format.
#
# Display the updated list of subjects.

# %%
#Task 1
# Student Profile Creator

student_id=input("Enter student id:")
student_name=input("Enter student name:")
student_age=input("Enter age:")
Favourite_subject=input("Enter Favourite_subject:")

print("\n-----Student Profile-----")
print("Student_ID : ",student_id)
print("Student_Name : ",student_name)
print("Student_Age : ",student_age)
print("Favourite_subject : ",Favourite_subject)
